# %%
from modules.parser import ParserName
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from modules.parser import ParserName
#
# File ~/Desktop/MAINFRAME/School/Year 3/Year3Sem1/Advanced Programming with Data/shared/DS3500_HW7/modules/parser.py:11
#       9 import random as rnd
#      10 import matplotlib.pyplot as plt
# ---> 11 from visualization import NatLanGraphs
#      14 class ParserName:
#      16     def __init__(self):
#
# ModuleNotFoundError: No module named 'DS3500_HW7'
